# %% [markdown]
# Q1. Take your roll number. Extract its individual digits, and multiply each digit by 10 to form your list L (10
# numbers in list now).
# i. Print L

# %%
a=1024170208
l=[]
while(a>0):
    l.append((a%10)*10)
    a//=10
l.reverse()
l
# Out:
# [10, 0, 20, 40, 10, 70, 0, 20, 0, 80]

# %% [markdown]
# ii. Add two numbers of your choice to L — one using append() and one using insert() at a specific position.
# Print L after each and explain in a comment what changed.

# %%
# Using append()
l.append(40)
l   # 40 is added at the end

# Using insert()
l.insert(4, 12)
l  # 12 is inserted at index 4
# Out:
# [10, 0, 20, 40, 12, 10, 70, 0, 20, 0, 80, 40]

# %% [markdown]
# iii. Remove two elements from L — one using remove() and one using pop(). Print L after each.

# %%
# Using remove()
l.remove(40)
print(l)
# Using append()
l.pop(2)
print(l)
# Out:
# [10, 0, 20, 12, 10, 70, 0, 20, 0, 80, 40]
# [10, 0, 12, 10, 70, 0, 20, 0, 80, 40]

# %% [markdown]
# iv. Sort L in ascending order using sort(), then descending order using sort(reverse=True). Print both.

# %%
# Sort in ascending order
l.sort()
print("Ascending:", l)

# Sort in descending order
l.sort(reverse=True)
print("Descending:", l)
# Out:
# Ascending: [0, 0, 0, 10, 10, 12, 20, 40, 70, 80]
# Descending: [80, 70, 40, 20, 12, 10, 10, 0, 0, 0]

# %% [markdown]
# v. Use slicing to print the first three elements and the last three elements of L in a single line each.

# %%
print("First three elements:", l[:3])
print("Last three elements:", l[-3:])
# Out:
# First three elements: [80, 70, 40]
# Last three elements: [0, 0, 0]

# %% [markdown]
# vi. Use list comprehension to create a new list containing only the elements of L that are greater than the
# average of L.

# %%
l1=[i for i in l if i>(sum(l)/len(l))]
l1
# Out:
# [80, 70, 40]

# %% [markdown]
# Q2. Create a tuple named scores containing 8 marks: use the first 8 values from your list L in Q1.
# i. Find the highest score and its index in the tuple, and the lowest score and how many times it appears.

# %%
a=1024170208
l=[]
while(a>0):
    l.append((a%10)*10)
    a//=10
l.reverse()
l
# Out:
# [10, 0, 20, 40, 10, 70, 0, 20, 0, 80]

# %%
scores = tuple(l[:8])
scores
# Out:
# (10, 0, 20, 40, 10, 70, 0, 20)

# %%
h = max(scores)
h_index = scores.index(h)

l = min(scores)
l_count = scores.count(l)

print("Highest score:", h)
print("Index of highest score:", h_index)
print("Lowest score:", l)
print("Number of times lowest appears:", l_count)
# Out:
# Highest score: 70
# Index of highest score: 5
# Lowest score: 0
# Number of times lowest appears: 2

# %% [markdown]
# ii. Reverse the tuple and return the result as a list (tuples themselves cannot be reversed in place —
# explain why in a one-line comment, referring to tuple immutability).

# %%
reversed_scores = list(scores[::-1])

print(reversed_scores)
# Tuples are immutable, so their elements cannot be changed or reversed in place.
# Out:
# [20, 0, 70, 10, 40, 20, 0, 10]

# %% [markdown]
# iii. Ask the user to input a score. Print its first occurrence index if present in the tuple, or a not present
# message if not.

# %%
score = int(input("Enter a score: "))

if score in scores:
    print("Index:", scores.index(score))
else:
    print("Score not present")
# Out:
# Enter a score: 70
# Index: 5

# %% [markdown]
# iv. Attempt to change one element of the tuple directly (e.g., scores[0] = 100). Run it, capture the error
# Python raises, and explain in one line why this happens and how it differs from a list.

# %%
scores[0] = 100
# Tuples are immutable, so their elements cannot be changed; lists are mutable and can be changed.
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_499/1793785932.py in <cell line: 0>()
# ----> 1 scores[0] = 100
#       2 # Tuples are immutable, so their elements cannot be changed; lists are mutable and can be changed.
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# v. Unpack the tuple into a first score, a second score, and all remaining scores using the * operator in a
# single line of unpacking.

# %%
first, second, *remaining = scores

print(first)
print(second)
print(remaining)
# Out:
# 10
# 0
# [20, 40, 10, 70, 0, 20]

# %% [markdown]
# Q3. Set the random seed to your own roll number using random.seed(your_roll_number) before generating
# your numbers — this keeps your list random-looking but reproducible and unique to you (a different seed
# produces a different list, so this cannot be copied from a classmate).
# i. Generate a list of 100 random numbers between 100 and 900 (inclusive).

# %%
import random

random.seed(1024170208)
numbers = [random.randint(100, 900) for i in range(100)]
print(numbers)
# Out:
# [410, 801, 350, 856, 849, 464, 269, 493, 220, 682, 240, 556, 329, 239, 570, 143, 230, 478, 183, 204, 519, 133, 720, 845, 815, 690, 640, 305, 862, 689, 324, 547, 289, 490, 881, 473, 231, 842, 554, 493, 621, 293, 756, 301, 213, 356, 427, 473, 719, 507, 678, 236, 114, 468, 437, 632, 581, 139, 671, 569, 215, 686, 224, 140, 560, 574, 256, 777, 132, 852, 659, 388, 237, 262, 395, 520, 251, 319, 703, 403, 619, 418, 252, 313, 544, 716, 337, 834, 431, 527, 418, 484, 453, 583, 498, 428, 223, 376, 773, 229]

# %% [markdown]
# ii. Count and print all odd numbers in the list.

# %%
count=0
for i in numbers:
    if i%2!=0:
        count+=1
        print(i)
print("Count of odd numbers:",count)
# Out:
# 801
# 849
# 269
# 493
# 329
# 239
# 143
# 183
# 519
# 133
# 845
# 815
# 305
# 689
# 547
# 289
# 881
# 473
# 231
# 493
# 621
# 293
# 301
# 213
# 427
# 473
# 719
# 507
# 437
# 581
# 139
# 671
# 569
# 215
# 777
# 659
# 237
# 395
# 251
# 319
# 703
# 403
# 619
# 313
# 337
# 431
# 527
# 453
# 583
# 223
# 773
# 229
# Count of odd numbers: 52

# %% [markdown]
# iii. Count and print all even numbers in the list.

# %%
count=0
for i in numbers:
    if i%2==0:
        count+=1
        print(i)
print("Count of even numbers:",count)
# Out:
# 410
# 350
# 856
# 464
# 220
# 682
# 240
# 556
# 570
# 230
# 478
# 204
# 720
# 690
# 640
# 862
# 324
# 490
# 842
# 554
# 756
# 356
# 678
# 236
# 114
# 468
# 632
# 686
# 224
# 140
# 560
# 574
# 256
# 132
# 852
# 388
# 262
# 520
# 418
# 252
# 544
# 716
# 834
# 418
# 484
# 498
# 428
# 376
# Count of even numbers: 48

# %% [markdown]
# iv. Count and print all prime numbers in the list, and additionally build the actual list of prime numbers
# found using list comprehension.

# %%
def isPrime(n):
    if n < 2:
        return False

    for i in range(2, int(n/2) + 1):
        if n % i == 0:
            return False

    return True

prime_numbers = []
for x in numbers:
    if isPrime(x):
        prime_numbers.append(x)

print(prime_numbers)
print("Count of prime numbers:", len(prime_numbers))
# Out:
# [269, 239, 547, 881, 293, 719, 139, 569, 659, 251, 619, 313, 337, 431, 223, 773, 229]
# Count of prime numbers: 17

# %% [markdown]
# v. Print the number that occurs most frequently in your list, and how many times it occurs.

# %%
m = max(numbers, key=(numbers.count))
m,numbers.count(m)
# Out:
# (493, 2)

# %% [markdown]
# Q4. Using the same 8 digits of your roll number from Q1 (before multiplying by 10), create set A = {digit × 7 for
# each digit} and set B = {digit × 9 for each digit}. Print both sets.
# vi. Find the union of A and B — all unique values across both sets.

# %%
digits = [1, 0, 2, 4, 1, 7, 0, 2]
A = {d * 7 for d in digits}
B = {d * 9 for d in digits}

print("A =", A)
print("B =", B)

print("Union =", A.union(B))
# Out:
# A = {0, 7, 14, 49, 28}
# B = {0, 36, 9, 18, 63}
# Union = {0, 36, 7, 9, 14, 49, 18, 28, 63}

# %% [markdown]
# vii. Find the intersection of A and B — values common to both.

# %%
print("Intersection =", A.intersection(B))
# Out:
# Intersection = {0}

# %% [markdown]
# viii. Find A − B and B − A separately (not combined) using difference(), and explain in one line how this
# differs from symmetric_difference().

# %%
print("A - B =", A.difference(B))
print("B - A =", B.difference(A))
# difference() gives elements present in one set but not the other.
# symmetric_difference() gives elements unique to both sets together.
# Out:
# A - B = {49, 28, 14, 7}
# B - A = {9, 18, 36, 63}

# %% [markdown]
# ix. Find the symmetric difference of A and B.

# %%
print("Symmetric Difference =", A.symmetric_difference(B))
# Out:
# Symmetric Difference = {7, 9, 14, 18, 28, 36, 49, 63}

# %% [markdown]
# x. Check whether A is a subset of B, and whether B is a superset of A, using issubset() and issuperset().

# %%
print("A is subset of B:", A.issubset(B))
print("B is superset of A:", B.issuperset(A))
# Out:
# A is subset of B: False
# B is superset of A: False

# %% [markdown]
# xi. Ask the user to input a value X. Remove X from set A if present using discard() (not remove()) — explain
# in one line why discard() is safer than remove() when you're not sure the value exists.

# %%
x = int(input("Enter X: "))
A.discard(x)
print("A after discard:", A)
# discard() is safer because it does not raise an error if the value is not present.
# Out:
# Enter X: 22
# A after discard: {0, 7, 14, 49, 28}

# %% [markdown]
# Q5. Consider the following dictionary:
# my_dict = {
# "name": "<your name>",
# "roll_no": "<your roll number>",
# "branch": "<your branch>",
# "age": <your age>,
# "city": "<your home city>"
# }
# i. Rename the key “city” to “location” without changing its value (do not just recreate the dictionary by
# hand — use pop() or dictionary comprehension so the code would work for any dictionary).

# %%
my_dict = {
    "name": "Vish",
    "roll_no": 1024170208,
    "branch": "Copc",
    "age": 20,
    "city": "Patiala"
}

my_dict["location"] = my_dict.pop("city")
print(my_dict)
# Out:
# {'name': 'Vish', 'roll_no': 1024170208, 'branch': 'Copc', 'age': 20, 'location': 'Patiala'}

# %% [markdown]
# ii. Add a new key “cgpa” with your CGPA as its value.

# %%
my_dict["cgpa"] = 8.2
print(my_dict)
# Out:
# {'name': 'Vish', 'roll_no': 1024170208, 'branch': 'Copc', 'age': 20, 'location': 'Patiala', 'cgpa': 8.2}

# %% [markdown]
# iii. Update the value of “age” by increasing it by 1.

# %%
my_dict["age"] += 1
print(my_dict)
# Out:
# {'name': 'Vish', 'roll_no': 1024170208, 'branch': 'Copc', 'age': 21, 'location': 'Patiala', 'cgpa': 8.2}

# %% [markdown]
# iv. Delete the “branch” key using two different methods in two separate copies of the dictionary: once
# with pop() and once with the del keyword. Explain in one line how pop() differs from del (hint: what
# does each return?).

# %%
# Delete branch using pop()
dict1 = my_dict.copy()
removed = dict1.pop("branch")
print(dict1)

# Delete branch using del
dict2 = my_dict.copy()
del dict2["branch"]
print(dict2)

# pop() returns the removed value, while del only deletes the key-value pair.
# Out:
# {'name': 'Vish', 'roll_no': 1024170208, 'age': 21, 'location': 'Patiala', 'cgpa': 8.2}
# {'name': 'Vish', 'roll_no': 1024170208, 'age': 21, 'location': 'Patiala', 'cgpa': 8.2}

# %% [markdown]
# v. Iterate over your dictionary using .items() and print each key-value pair as “key → value”

# %%
for key, value in my_dict.items():
    print(key, "→", value)
# Out:
# name → Vish
# roll_no → 1024170208
# branch → Copc
# age → 21
# location → Patiala
# cgpa → 8.2

# %% [markdown]
# vi. Before accessing a key called “email” (which doesn't exist in your dictionary), check for its existence
# using the in keyword and print a safe fallback message instead of letting the program crash.

# %%
if "email" in my_dict:
    print(my_dict["email"])
else:
    print("Email key not present")
# Out:
# Email key not present

# %% [markdown]
# vii. Create a second dictionary friend_dict with the same 5 original keys but a friend's (fictional) details.
# Merge it with your own using the {**dict1, **dict2} syntax, and explain in one line which values “win”
# when both dictionaries share a key.

# %%
friend_dict = {
    "name": "Aman",
    "roll_no": 1024030253,
    "branch": "Coe",
    "age": 20,
    "city": "Ludhiana"
}

merged_dict = {**my_dict, **friend_dict}
print(merged_dict)
# When keys overlap, values from the second dictionary win.
# Out:
# {'name': 'Aman', 'roll_no': 1024030253, 'branch': 'Coe', 'age': 20, 'location': 'Patiala', 'cgpa': 8.2, 'city': 'Ludhiana'}

# %% [markdown]
# viii. Use dictionary comprehension to create a new dictionary containing only the key-value pairs from your
# original dictionary where the value is a string.

# %%
string_dict = {
    key: value
    for key, value in my_dict.items()
    if isinstance(value, str)
}
print(string_dict)
# Out:
# {'name': 'Vish', 'branch': 'Copc', 'location': 'Patiala'}
